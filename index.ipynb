# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
keys = get_keys("/Users/wblak/.secret/yelp_api.json")

api_key = keys['api_key']

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!

# %%
import requests

# %%
url = #This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
#   File "<ipython-input-4-99271e4af878>", line 1
#     url = #This will be our next step
#                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
print(response)
print(response.text[:1000])
# Out:
# <Response [200]>
# {"businesses": [{"id": "ysqgdbSrezXgVwER2kQWKA", "alias": "julianas-pizza-brooklyn-5", "name": "Juliana's Pizza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg", "review_count": 2183, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 4.5, "coordinates": {"latitude": 40.7026153030093, "longitude": -73.9934159993549}, "transactions": [], "price": "$$", "location": {"address1": "19 Old Fulton St", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11201", "country": "US", "state": "NY", "display_address": ["19 Old Fulton St", "Brooklyn, NY 11201"]}, "phone": "+17185966700", "display_phone": "(718) 596-6700", "distance": 323.20506308227306}, {"id": "zj8Lq1T8KIC5zwFief15jg", "alias": "prince-street-pizza-new-york-2",

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
response.json()['businesses'][:5]
# Out:
# [{'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-pizza-brooklyn-5',
#   'name': "Juliana's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg',
#   'review_count': 2183,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7026153030093,
#    'longitude': -73.9934159993549},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 323.20506308227306},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg',
#   'review_count': 3538,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7229087705545,
#    'longitude': -73.9944863319397},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1941.9638172538225},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg',
#   'review_count': 6099,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 1798.9959778083735},
#  {'id': '2ggi1luerd3Mf_C82JvCYg',
#   'alias': 'grimaldis-pizzeria-brooklyn-4',
#   'name': "Grimaldi's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnocNRTl04953MdDXH9y7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg',
#   'review_count': 4599,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188584300',
#   'display_phone': '(718) 858-4300',
#   'distance': 330.34746206527655},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=dYH2fvCAxNsGsdsmyzGicg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dYH2fvCAxNsGsdsmyzGicg',
#   'review_count': 2222,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 1932.9467701334759}]

# %%
import pandas as pd
df = pd.DataFrame(response.json()['businesses'])
df
# Out:
#                         id                                  alias  \
# 0   ysqgdbSrezXgVwER2kQWKA              julianas-pizza-brooklyn-5
# 1   zj8Lq1T8KIC5zwFief15jg         prince-street-pizza-new-york-2
# 2   WIhm0W9197f_rRtDziq5qQ             lombardis-pizza-new-york-4
# 3   2ggi1luerd3Mf_C82JvCYg          grimaldis-pizzeria-brooklyn-4
# 4   WG639VkTjmK5dzydd1BBJA                    rubirosa-new-york-2
# 5   C8j0q4Ma_S5hBGuAI-aaww                 di-fara-pizza-brooklyn
# 6   xxgcU_oFIox_pAmroo9WwA            front-street-pizza-brooklyn
# 7   FhXjAc6nKLf414KxYujUHw                    robertas-brooklyn-2
# 8   v1DHGRNCH9247WLYoaoA9A          l-industrie-pizzeria-brooklyn
# 44  H_Q1dEqnrz7GzQiArdsrNw              sauce-pizzeria-new-york-5
# 45  KEgdfVEVVgJFnGFiLNPDzQ            sofia-pizza-shoppe-new-york
# 46  G4KNXsc7F49OzkW7I28JCg                    best-pizza-brooklyn
# 47  IZ9-5z45wc3Oh_jlnX_Kcg                   giuseppinas-brooklyn
# 48  X8Hl9OezX-Yr9Jir3fsF7g                       posto-new-york-4
# 49  3VJwpmmeoPlCN3J5p5miEQ  brooklyns-homeslice-pizzeria-brooklyn
#
#                              name  \
# 0                 Juliana's Pizza
# 1             Prince Street Pizza
# 2                Lombardi's Pizza
# 3             Grimaldi's Pizzeria
# 4                        Rubirosa
# 5                   Di Fara Pizza
# 6              Front Street Pizza
# 7                       Roberta's
# 8            L'industrie Pizzeria
# 9                       Piz-zetta
# 10          Bleecker Street Pizza
# 11                    Joe's Pizza
# 12                    Joe's Pizza
# 13          L & B Spumoni Gardens
# 14                    Joe's Pizza
# 15                      Ignazio's
# 16               Patsy's Pizzeria
# 17                    Joe's Pizza
# 18            99 Cent Fresh Pizza
# 19                    Joe's Pizza
# 20                  Scarr's Pizza
# 21            Il Porto Ristorante
# 22               NY Pizza Suprema
# 23                   Speedy Romeo
# 24                   Dellarocco's
# 25           Village Square Pizza
# 26             Williamsburg Pizza
# 27      Artichoke Basille's Pizza
# 28                     Milkflower
# 29                 Champion Pizza
# 30             Sottocasa Pizzeria
# 31                         Gruppo
# 32                  Baker's Pizza
# 33                  Lil Frankie's
# 34      John's of Bleecker Street
# 35    Table 87 - Brooklyn Heights
# 36           Archie's Bar & Pizza
# 37               Lombardi's pizza
# 38              Underground Pizza
# 39                     Grimaldi's
# 40              Vinnie's Pizzeria
# 41             East Village Pizza
# 42                   Nick's Pizza
# 43                      Saraghina
# 44                 Sauce Pizzeria
# 45             Sofia Pizza Shoppe
# 46                     Best Pizza
# 47                   Giuseppina's
# 48                          Posto
# 49  Brooklyn's Homeslice Pizzeria
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/clscwg...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOy...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_h...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/KnocNR...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9q...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/SRL_Rz...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/9L4viD...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/iiFPnK...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2Q...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/8X6uFK...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/Wwmb6X...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/RjZTK7...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIh...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/7RQebf...      False
# 20  https://s3-media4.fl.yelpcdn.com/bphoto/k3iXzX...      False
# 21  https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bk...      False
# 22  https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXn...      False
# 23  https://s3-media4.fl.yelpcdn.com/bphoto/fJgnkr...      False
# 24  https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2...      False
# 25  https://s3-media2.fl.yelpcdn.com/bphoto/2z6BPA...      False
# 26  https://s3-media1.fl.yelpcdn.com/bphoto/uMXAMU...      False
# 27  https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_...      False
# 28  https://s3-media3.fl.yelpcdn.com/bphoto
# 25  https://www.yelp.com/biz/village-square-pizza-...           133
# 26  https://www.yelp.com/biz/williamsburg-pizza-ne...           225
# 27  https://www.yelp.com/biz/artichoke-basilles-pi...          3959
# 28  https://www.yelp.com/biz/milkflower-astoria?ad...           632
# 29  https://www.yelp.com/biz/champion-pizza-new-yo...           313
# 30  https://www.yelp.com/biz/sottocasa-pizzeria-br...           624
# 31  https://www.yelp.com/biz/gruppo-new-york-4?adj...           253
# 32  https://www.yelp.com/biz/bakers-pizza-new-york...           214
# 33  https://www.yelp.com/biz/lil-frankies-new-york...          1105
# 34  https://www.yelp.com/biz/johns-of-bleecker-str...          2016
# 35  https://www.yelp.com/biz/table-87-brooklyn-hei...           264
# 36  https://www.yelp.com/biz/archies-bar-and-pizza...           345
# 37  https://www.yelp.com/biz/lombardis-pizza-new-y...           141
# 38  https://www.yelp.com/biz/underground-pizza-new...           290
# 39  https://www.yelp.com/biz/grimaldis-new-york-4?...           746
# 40  https://www.yelp.com/biz/vinnies-pizzeria-broo...           668
# 41  https://www.yelp.com/biz/east-village-pizza-ne...           263
# 42  https://www.yelp.com/biz/nicks-pizza-new-york?...           530
# 43  https://www.yelp.com/biz/saraghina-brooklyn?ad...           862
# 44  https://www.yelp.com/biz/sauce-pizzeria-new-yo...            44
# 45  https://www.yelp.com/biz/sofia-pizza-shoppe-ne...           193
# 46  https://www.yelp.com/biz/best-pizza-brooklyn?a...           589
# 47  https://www.yelp.com/biz/giuseppinas-brooklyn?...           313
# 48  https://www.yelp.com/biz/posto-new-york-4?adju...           603
# 49  https://www.yelp.com/biz/brooklyns-homeslice-p...           123
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 3              [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 4   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 9   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 12             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 20             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 21  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 22             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 23  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 24  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 25             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 26             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 27             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 28             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 29             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 30  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 31  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 32             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 33  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 34             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 35  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 36  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 38  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 39             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 40  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 41  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 42  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 43  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 44             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 46             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 47             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 48  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 49             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.7026153030093, 'longitude': -7...                  []
# 1   {'latitude': 40.7229087705545, 'longitude': -7...  [pickup, delivery]
# 2   {'latitude': 40.7215934960083, 'longitude': -7...  [pickup, delivery]
# 3   {'latitude': 40.702583, 'longitude': -73.9932413}  [delivery, pickup]
# 4    {'latitude': 40.722766, 'longitude': -73.996233}  [pickup, delivery]
# 5    {'latitude': 40.625093, 'longitude': -73.961531}  [pickup, delivery]
# 6      {'latitude': 40.70244, 'longitude': -73.98943}  [pickup, delivery]
# 7   {'latitude': 40.705043534338, 'longitude': -73...  [delivery, pickup]
# 8      {'latitude': 40.71162, 'longitude': -73.95783}  [pickup, delivery]
# 9   {'latitude': 40.6912834070746, 'longitude': -7...  [pickup, delivery]
# 10  {'latitude': 40.7320627016512, 'longitude': -7...  [pickup, delivery]
# 11  {'latitude': 40.7101297729083, 'longitude': -7...  [pickup, delivery]
# 12     {'latitude': 40.73331, 'longitude': -73.98763}  [pickup, delivery]
# 13   {'latitude': 40.594715, 'longitude': -73.981316}  [pickup, delivery]
# 14  {'latitude': 40.7545841255557, 'longitude': -7...  [pickup, delivery]
# 15   {'latitude': 40.703137, 'longitude': -73.993608}  [pickup, delivery]
# 16  {'latitude': 40.6818695, 'longitude': -73.976181}  [pickup, delivery]
# 17   {'latitude': 40.730554, 'longitude': -74.002136}                  []
# 18     {'latitude': 40.76458, 'longitude': -73.98247}  [pickup, delivery]
# 19    {'latitude': 40.71691, 'longitude': -73.958987}  [pickup, delivery]
# 20      {'latitude': 40.71534, 'longitude': -73.9914}  [pickup, delivery]
# 21  {'latitude': 40.6974427, 'longitude': -73.9675...  [pickup, delivery]
# 22  {'latitude': 40.7502059936523, 'longitude': -7...  [pickup, delivery]
# 23     {'latitude': 40.71951, 'longitude': -73.98514}  [pickup, delivery]
# 24  {'latitude': 40.6950309, 'longitude': -73.9961...  [pickup, delivery]
# 25     {'latitude': 40.72748, 'longitude': -73.98268}  [pickup, delivery]
# 26     {'latitude': 40.71822, 'longitude': -73.99123}  [pickup, delivery]
# 27  {'latitude': 40.7321124557704, 'longitude': -7...  [pickup, delivery]
# 28  {'latitude': 40.7628961, 'longitude': -73.9207...  [delivery, pickup]
# 29  {'latitude': 40.7215270996094, 'longitude': -7...  [pickup, delivery]
# 30   {'latitude': 40.688285, 'longitude': -73.989006}          [delivery]
# 31     {'latitude': 40.72474, 'longitude': -73.98161}  [pickup, delivery]
# 32   {'latitude': 40.7294399, 'longitude': -73.98125}  [pickup, delivery]
# 33   {'latitude': 40.723625, 'longitude': -73.988555}  [pickup, delivery]
# 34     {'latitude': 40.73158, 'longitude': -74.00332}  [pickup, delivery]
# 35  {'latitude': 40.691219329834, 'longitude': -73...  [pickup, delivery]
# 36   {'latitude': 40.699705, 'longitude': -73.928512}  [pickup, delivery]
# 37      {'latitude': 40.74623, 'longitude': -73.9974}  [pickup, delivery]
# 38     {'latitude': 40.70499, 'longitude': -74.00961}  [pickup, delivery]
# 39  {'latitude': 40.7412157, 'longitude': -73.9938...  [delivery, pickup]
# 40     {'latitude': 40.7189, 'longitude': -73.956843}  [pickup, delivery]
# 41   {'latitude': 40.728199, 'longitude': -73.985182}  [pickup, delivery]
# 42     {'latitude': 40.78272, 'longitude': -73.94781}  [pickup, delivery]
# 43  {'latitude': 40.6835063, 'longitude': -73.9352...  [pickup, delivery]
# 44   {'latitude': 40.7204894, 'longitude': -73.98927}  [pickup, delivery]
# 45     {'latitude': 40.75674, 'longitude': -73.96431}  [pickup, delivery]
# 46      {'latitude': 40.7156, 'longitude': -73.95352}  [pickup, delivery]
# 47  {'latitude': 40.6603430973463, 'longitude': -7...            [pickup]
# 48     {'latitude': 40.73483, 'longitude': -73.98282}  [pickup, delivery]
# 49   {'latitude': 40.680702, 'longitude': -73.967455}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 1      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 2     $$  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 3     $$  {'address1': '1 Front St', 'address2': '', 'ad...  +17188584300
# 4     $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
# 5     $$  {'address1': '1424 Ave J', 'address2': '', 'ad...  +17182581367
# 6      $  {'address1': '80 Front St', 'address2': '', 'a...  +17188753700
# 7     $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 8      $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 9      $  {'address1': '90 Livingston St', 'address2': '...  +17184227878
# 10     $  {'address1': '69 7th Ave S', 'address2': None,...  +12129244466
# 11     $  {'address1': '124 Fulton St', 'address2': '', ...  +12122670860
# 12     $  {'address1': '150 E 14th St', 'address2': '', ...  +12123889474
# 13     $  {'address1': '2725 86th St', 'address2': '', '...  +17184491230
# 14     $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 15    $$  {'address1': '4 Water St', 'address2': '', 'ad...  +17185222100
# 16    $$  {'address1': '450 Dean St', 'address2': '', 'a...  +17186222268
# 17     $  {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
# 18     $  {'address1': '1723 Broadway', 'address2': '', ...  +12122452155
# 19     $  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 20     $  {'address1': '22 Orchard St', 'address2': '', ...  +12123343481
# 21    $$  {'address1': '37 Washington Ave', 'address2': ...  +17186240954
# 22     $  {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 23    $$  {'address1': '63 Clinton St', 'address2': '', ...  +12125296300
# 24    $$  {'address1': '214 Hicks St', 'address2': None,...  +17188581010
# 25     $  {'address1': '147 Ave A', 'address2': None, 'a...  +19176757709
# 26     $  {'address1': '277 Broome St', 'address2': '', ...  +12122264455
# 27     $  {'address1': '321 E 14th St', 'address2': '', ...  +12122282004
# 28    $$  {'address1': '3412 31st Ave', 'address2': '', ...  +17182041300
# 29     $  {'address1': '17 Cleveland Pl', 'address2': No...  +12122263777
# 30    $$  {'address1': '298 Atlantic Ave', 'address2': N...  +17188528758
# 31    $$  {'address1': '98 Ave B', 'address2': '', 'addr...  +12129952100
# 32     $  {'address1': '201 Avenue A', 'address2': None,...  +12127777477
# 33    $$  {'address1': '19 1st Ave', 'address2': '', 'ad...  +12124204900
# 34    $$  {'address1': '278 Bleecker St', 'address2': ''...  +12122431680
# 35    $$  {'address1': '87 Atlantic Ave', 'address2': ''...  +17187979300
# 36    $$  {'address1': '128 Central Ave', 'address2': No...  +13479152244
# 37    $$  {'address1': '290 8th Ave', 'address2': '', 'a...  +12122561973
# 38     $  {'address1': '3 Hanover Sq', 'address2': '', '...  +12124254442
# 39    $$  {'address1': '656 6th Ave', 'address2': '', 'a...  +16464845665
# 40     $  {'address1': '148 Bedford Ave', 'address2': ''...  +17187827078
# 41     $  {'address1': '145 1st Ave', 'address2': '', 'a...  +12125294545
# 42    $$  {'address1': '1814 2nd Ave', 'address2': '', '...  +12129875700
# 43    $$  {'address1': '435 Halsey St', 'address2': '', ...  +17185740010
# 44     $  {'address1': '84 Rivington St', 'address2': ''...  +19176757240
# 45     $  {'address1': '989 1st Ave', 'address2': '', 'a...  +12128888816
# 46     $  {'address1': '33 Havemeyer St', 'address2': ''...  +17185992210
# 47    $$  {'address1': '691 6th Ave', 'address2': None, ...  +17184995052
# 48    $$  {'address1': '310 2nd Ave', 'address2': None, ...  +12127161200
# 49     $  {'address1': '567 Vanderbilt Ave', 'address2':...  +17183999000
#
#      display_phone      distance
# 0   (718) 596-6700    323.205063
# 1   (212) 966-4100   1941.963817
# 2   (212) 941-7994   1798.995978
# 3   (718) 858-4300    330.347462
# 4   (212) 965-0500   1932.946770
# 5   (718) 258-1367   9352.269073
# 6   (718) 875-3700    550.439226
# 7   (718) 417-1118   5118.690592
# 8   (718) 599-0002   3145.016041
# 9   (718) 422-7878   1605.117670
# 10  (212) 924-4466   3072.954045
# 11  (212) 267-0860   1245.942863
# 12  (212) 388-9474   3133.913077
# 13  (718) 449-1230  12361.163423
# 14  (646) 559-4878   5498.444221
# 15  (718) 522-2100    263.042502
# 16  (718) 622-2268   3034.989400
# 17  (212) 366-1182   2869.177466
# 18  (212) 245-2155   6652.683138
# 19  (718) 388-2216   3239.296657
# 20  (212) 334-3481   1125.784330
# 21  (718) 624-0954   2433.857388
# 22  (212) 594-8939   4977.847939
# 23  (212) 529-6300   1743.124903
# 24  (718) 858-1010   1170.270033
# 25  (917) 675-7709   2640.263835
# 26  (212) 226-4455   1448.619038
# 27  (212) 228-2004   3091.822114
# 28  (718) 204-1300   8902.311957
# 29  (212) 226-3777   1801.476444
# 30  (718) 852-8758   1959.787002
# 31  (212) 995-2100   2395.292393
# 32  (212) 777-7477   2886.890664
# 33  (212) 420-4900   2079.287843
# 34  (212) 243-1680   3010.899021
# 35  (718) 797-9300   1602.590812
# 36  (347) 915-2244   5582.687406
# 37  (212) 256-1973   4544.250019
# 38  (212) 425-4442   1295.765274
# 39  (646) 484-5665   3977.673651
# 40  (718) 782-7078   3489.007992
# 41  (212) 529-4545   2643.857504
# 42  (212) 987-5700   9442.562366
# 43  (718) 574-0010   5547.145092
# 44  (917) 675-7240   1725.617693
# 45  (212) 888-8816   6230.328427
# 46  (718) 599-2210   3621.346198
# 47  (718) 499-5052   5023.853129
# 48  (212) 716-1200   3407.292341
# 49  (718) 399-9000   3562.218209

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
